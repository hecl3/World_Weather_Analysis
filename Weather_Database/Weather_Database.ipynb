# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time module.
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=200)
lngs = np.random.uniform(low=-180.000, high=180.000, size=200)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 144

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#url

# %%
import pprint
import json

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    city_weather = requests.get(city_url).json()
#     print(city_weather)
    print(json.dumps(city_weather, indent=4, sort_keys=True))
#     pprint.pprint(city_weather)
#     break
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
#         city_weather = requests.get(city_url).json()
#         print(json.dumps(city_weather, indent=4, sort_keys=True))
#         print(city_weather)
#         break
        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=bredasdorp
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.5322,
#         "lon": 20.0403
#     },
#     "dt": 1651022935,
#     "id": 1015776,
#     "main": {
#         "feels_like": 52.16,
#         "grnd_level": 1015,
#         "humidity": 83,
#         "pressure": 1024,
#         "sea_level": 1024,
#         "temp": 53.24,
#         "temp_max": 53.24,
#         "temp_min": 53.24
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1651036325,
#         "sunset": 1651075359
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 32,
#         "gust": 3.53,
#         "speed": 3.44
#     }
# }
# Processing Record 1 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=ushuaia
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1651022937,
#     "id": 3833367,
#     "main": {
#         "feels_like": 30.04,
#         "humidity": 81,
#         "pressure": 992,
#         "temp": 38.86,
#         "temp_max": 38.86,
#         "temp_min": 38.86
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1650973472,
#         "sunset": 1651007829,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 16.11
#     }
# }
# Processing Record 2 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=asind
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 25.7333,
#         "lon": 74.3333
#     },
#     "dt": 1651023152,
#     "id": 1278278,
#     "main": {
#         "feels_like": 84.49,
#         "grnd_level": 955,
#         "humidity": 28,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 87.06,
#         "temp_max": 87.06,
#         "temp_min": 87.06
#     },
#     "name": "\u0100sind",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1651019357,
#         "sunset": 1651066268
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 283,
#         "gust": 29.44,
#         "speed": 16.58
#     }
# }
# Processing Record 3 of Set 1 | asind
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=mehtar+lam
# {
#     "base": "stations",
#     "clouds": {
#         "all": 13
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 34.6714,
#         "lon": 70.2094
#     },
#     "dt": 1651023152,
#     "id": 1133574,
#     "main": {
#         "feels_like": 76.71,
#         "grnd_level": 924,
#         "humidity": 19,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 78.3,
#         "temp_max": 78.3,
#         "temp_min": 78.3
#     },
#     "name": "Mehtar L\u0101m",
#     "sys": {
#         "country": "AF",
#         "sunrise": 1651019609,
#         "sunset": 1651067996
#     },
#     "timezone": 16200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "gust": 5.66,
#         "speed": 4.7
#     }
# }
# Processing Record 4 of Set 1 | mehtar lam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=labutta
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Processing Record 5 of Set 1 | labutta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=vaini
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2,
#         "lon": -175.2
#     },
#     "dt": 1651023014,
#     "id": 4032243,
#     "main": {
#         "feels_like": 78.96,
#         "humidity": 61,
#         "pressure": 1015,
#         "temp": 78.96,
#         "temp_max": 78.96,
#         "temp_min": 78.96
#     },
#     "name": "Vaini",
#     "sys": {
#         "country": "TO",
#         "id": 7285,
#         "sunrise": 1651082203,
#         "sunset": 1651123187,
#         "type": 1
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 14.97
#     }
# }
# Processing Record 6 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=souillac
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.5167,
#         "lon": 57.5167
#     },
#     "dt": 1651023153,
#     "id": 933995,
#     "main": {
#         "feels_like": 74.98,
#         "humidity": 88,
#         "pressure": 1011,
#         "temp": 73.78,
#         "temp_max": 73.78,
#         "temp_min": 73.78
#     },
#     "name": "Souillac",
#     "sys": {
#         "country": "MU",
#         "id": 2061,
#         "sunrise": 1651026291,
#         "sunset": 1651067406,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 9.22
#     }
# }
# Processing Record 7 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=sembe
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 1.6481,
#         "lon": 14.5806
#     },
#     "dt": 1651023153,
#     "id": 2255304,
#     "main": {
#         "feels_like": 69.85,
#         "grnd_level": 961,
#         "humidity": 98,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 68.68,
#         "temp_max": 68.68,
#         "temp_min": 68.68
#     },
#     "name": "S\u00e9mb\u00e9",
#     "sys": {
#         "country": "CG",
#         "sunrise": 1651035250,
#         "sunset": 1651079055
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 277,
#         "gust": 2.77,
#         "speed": 2.01
#     }
# }
# Processing Record 8 of Set 1 | sembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=nikolskoye
# {
#     "base": "stations",
#     "clouds": {
#         "all": 67
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.7035,
#         "lon": 30.7861
#     },
#     "dt": 1651023154,
#     "id": 546105,
#     "main": {
#         "feels_like": 29.93,
#         "grnd_level": 1012,
#         "humidity": 94,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 34.05,
#         "temp_max": 34.88,
#         "temp_min": 32.72
#     },
#     "name": "Nikolskoye",
#     "sys": {
#         "country": "RU",
#         "id": 2034996,
#         "sunrise": 1651025249,
#         "sunset": 1651081277,
#         "type": 2
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 331,
#         "gust": 12.3,
#         "speed": 4.52
#     }
# }
# Processing Record 9 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=goderich
# {
#     "base": "stations",
#     "clouds": {
#         "all": 96
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.7501,
#         "lon": -81.7165
#     },
#     "dt": 1651023154,
#     "id": 5962442,
#     "main": {
#         "feels_like": 28.94,
#         "humidity": 86,
#         "pressure": 1021,
#         "temp": 34.11,
#         "temp_max": 35.91,
#         "temp_min": 33.91
#     },
#     "name": "Goderich",
#     "snow": {
#         "1h": 0.45
#     },
#     "sys": {
#         "country": "CA",
#         "id": 253,
#         "sunrise": 1650968771,
#         "sunset": 1651018969,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 127,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "speed": 5.75
#     }
# }
# Processing Record 10 of Set 1 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=gusau
# {
#     "base": "stations",
#     "clouds": {
#         "all": 86
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.1628,
#         "lon": 6.6614
#     },
#     "dt": 1651023154,
#     "id": 2339937,
#     "main": {
#         "feels_like": 81.86,
#         "grnd_level": 956,
#         "humidity": 17,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 84.92,
#         "temp_max": 84.92,
#         "temp_min": 84.92
#     },
#     "name": "Gusau",
#     "sys": {
#         "country": "NG",
#         "sunrise": 1651036513,
#         "sunset": 1651081592
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 234,
#         "gust": 8.25,
#         "speed": 7.11
#     }
# }
# Processing Record 11 of Set 1 | gusau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=jamestown
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.097,
#         "lon": -79.2353
#     },
#     "dt": 1651022941,
#     "id": 5122534,
#     "main": {
#         "feels_like": 32.2,
#         "humidity": 60,
#         "pressure": 1020,
#         "temp": 40.78,
#         "temp_max": 42.39,
#         "temp_min": 39.52
#     },
#     "name": "Jamestown",
#     "sys": {
#         "country": "US",
#         "id": 2008933,
#         "sunrise": 1650968368,
#         "sunset": 1651018181,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "gust": 26.46,
#         "speed": 17.27
#     }
# }
# Processing Record 12 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=vostok
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.4856,
#         "lon": 135.8833
#     },
#     "dt": 1651023155,
#     "id": 2013279,
#     "main": {
#         "feels_like": 19.08,
#         "grnd_level": 928,
#         "humidity": 98,
#         "pressure": 999,
#         "sea_level": 999,
#         "temp": 30.43,
#         "temp_max": 30.43,
#         "temp_min": 30.43
#     },
#     "name": "Vostok",
#     "snow": {
#         "1h": 1.74
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1651002563,
#         "sunset": 1651053522
#     },
#     "timezone": 36000,
#     "visibility": 32,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13d",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 281,
#         "gust": 32.06,
#         "speed": 16.42
#     }
# }
# Processing Record 13 of Set 1 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=artyk
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Processing Record 14 of Set 1 | artyk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=buin
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.7333,
#         "lon": -70.75
#     },
#     "dt": 1651023155,
#     "id": 3897774,
#     "main": {
#         "feels_like": 50.58,
#         "grnd_level": 962,
#         "humidity": 82,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": 51.84,
#         "temp_max": 51.84,
#         "temp_min": 51.84
#     },
#     "name": "Buin",
#     "sys": {
#         "country": "CL",
#         "id": 8486,
#         "sunrise": 1650971614,
#         "sunset": 1651010863,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 94,
#         "gust": 7.2,
#         "speed": 4.83
#     }
# }
# Processing Record 15 of Set 1 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=verkhoyansk
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 67.5447,
#         "lon": 133.385
#     },
#     "dt": 1651023155,
#     "id": 2013465,
#     "main": {
#         "feels_like": 15.46,
#         "grnd_level": 1001,
#         "humidity": 78,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 23.43,
#         "temp_max": 23.43,
#         "temp_min": 23.43
#     },
#     "name": "Verkhoyansk",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1650997689,
#         "sunset": 1651059595
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 17,
#         "gust": 8.5,
#         "speed": 6.64
#     }
# }
# Processing Record 16 of Set 1 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=bandar-e+torkaman
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Processing Record 17 of Set 1 | bandar-e torkaman
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=belushya+guba
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=saskylakh
# {
#     "base": "stations",
#     "clouds": {
#         "all": 97
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.9167,
#         "lon": 114.0833
#     },
#     "dt": 1651023156,
#     "id": 2017155,
#     "main": {
#         "feels_like": 16.47,
#         "grnd_level": 1020,
#         "humidity": 81,
#         "pressure": 1021,
#         "sea_level": 1021,
#         "temp": 16.47,
#         "temp_max": 16.47,
#         "temp_min": 16.47
#     },
#     "name": "Saskylakh",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1650999022,
#         "sunset": 1651067526
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 236,
#         "gust": 4.9,
#         "speed": 2.98
#     }
# }
# Processing Record 19 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=necochea
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -38.5473,
#         "lon": -58.7368
#     },
#     "dt": 1651023156,
#     "id": 3430443,
#     "main": {
#         "feels_like": 63.39,
#         "grnd_level": 993,
#         "humidity": 99,
#         "pressure": 995,
#         "sea_level": 995,
#         "temp": 62.76,
#         "temp_max": 62.76,
#         "temp_min": 62.76
#     },
#     "name": "Necochea",
#     "rain": {
#         "1h": 4.21
#     },
#     "sys": {
#         "country": "AR",
#         "sunrise": 1650969146,
#         "sunset": 1651007565
#     },
#     "timezone": -10800,
#     "visibility": 6263,
#     "weather": [
#         {
#             "description": "heavy intensity rain",
#             "icon": "10n",
#             "id": 502,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 254,
#         "gust": 17.74,
#         "speed": 7.47
#     }
# }
# Processing Record 20 of Set 1 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=rikitea
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.1203,
#         "lon": -134.9692
#     },
#     "dt": 1651023021,
#     "id": 4030556,
#     "main": {
#         "feels_like": 78.71,
#         "grnd_level": 1018,
#         "humidity": 71,
#         "pressure": 1021,
#         "sea_level": 1021,
#         "temp": 77.88,
#         "temp_max": 77.88,
#         "temp_min": 77.88
#     },
#     "name": "Rikitea",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1650986250,
#         "sunset": 1651027048
#     },
#     "timezone": -32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 92,
#         "gust": 23.82,
#         "speed": 20.92
#     }
# }
# Processing Record 21 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=horta
# {
#     "base": "stations",
#     "clouds": {
#         "all": 92
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.5333,
#         "lon": -28.6333
#     },
#     "dt": 1651023157,
#     "id": 3372988,
#     "main": {
#         "feels_like": 63.03,
#         "grnd_level": 1005,
#         "humidity": 94,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 62.65,
#         "temp_max": 62.65,
#         "temp_min": 62.65
#     },
#     "name": "Horta",
#     "sys": {
#         "country": "PT",
#         "sunrise": 1651042938,
#         "sunset": 1651092107
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 172,
#         "gust": 29.48,
#         "speed": 22.24
#     }
# }
# Processing Record 22 of Set 1 | horta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=avarua
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2078,
#         "lon": -159.775
#     },
#     "dt": 1651022937,
#     "id": 4035715,
#     "main": {
#         "feels_like": 94.3,
#         "humidity": 79,
#         "pressure": 1014,
#         "temp": 84.25,
#         "temp_max": 84.25,
#         "temp_min": 84.25
#     },
#     "name": "Avarua",
#     "sys": {
#         "country": "CK",
#         "id": 7271,
#         "sunrise": 1650992078,
#         "sunset": 1651033126,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 9.22
#     }
# }
# Processing Record 23 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=seybaplaya
# {
#     "base": "stations",
#     "clouds": {
#         "all": 57
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 19.65,
#         "lon": -90.6667
#     },
#     "dt": 1651023157,
#     "id": 3516685,
#     "main": {
#         "feels_like": 85.12,
#         "grnd_level": 1008,
#         "humidity": 71,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 81.18,
#         "temp_max": 81.18,
#         "temp_min": 81.18
#     },
#     "name": "Seybaplaya",
#     "sys": {
#         "country": "MX",
#         "sunrise": 1650973012,
#         "sunset": 1651019024
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 22,
#         "gust": 26.44,
#         "speed": 17.63
#     }
# }
# Processing Record 24 of Set 1 | seybaplaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=atuona
# {
#     "base": "stations",
#     "clouds": {
#         "all": 24
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.0333
#     },
#     "dt": 1651022940,
#     "id": 4020109,
#     "main": {
#         "feels_like": 79.83,
#         "grnd_level": 1003,
#         "humidity": 76,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 78.69,
#         "temp_max": 78.69,
#         "temp_min": 78.69
#     },
#     "name": "Atuona",
#     "rain": {
#         "1h": 0.53
#     },
#     "sys": {
#         "country": "PF",
#         "sunrise": 1650986392,
#         "sunset": 1651028857
#     },
#     "timezone": -34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 101,
#         "gust": 23.98,
#         "speed": 21.79
#     }
# }
# Processing Record 25 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=kawalu
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -7.3817,
#         "lon": 108.2082
#     },
#     "dt": 1651023157,
#     "id": 1640902,
#     "main": {
#         "feels_like": 84.92,
#         "grnd_level": 974,
#         "humidity": 82,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 80.19,
#         "temp_max": 80.19,
#         "temp_min": 80.19
#     },
#     "name": "Kawalu",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1651013312,
#         "sunset": 1651056056
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "gust": 1.72,
#         "speed": 0.51
#     }
# }
# Processing Record 26 of Set 1 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=hofn
# {
#     "base": "stations",
#     "clouds": {
#         "all": 43
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.2539,
#         "lon": -15.2082
#     },
#     "dt": 1651023158,
#     "id": 2630299,
#     "main": {
#         "feels_like": 34.23,
#         "grnd_level": 1026,
#         "humidity": 82,
#         "pressure": 1026,
#         "sea_level": 1026,
#         "temp": 40.84,
#         "temp_max": 40.84,
#         "temp_min": 40.84
#     },
#     "name": "Hofn",
#     "sys": {
#         "country": "IS",
#         "sunrise": 1651034776,
#         "sunset": 1651093825
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 42,
#         "gust": 12.46,
#         "speed": 11.12
#     }
# }
# Processing Record 27 of Set 1 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=kolokani
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.5728,
#         "lon": -8.0339
#     },
#     "dt": 1651023158,
#     "id": 2454955,
#     "main": {
#         "feels_like": 79.39,
#         "grnd_level": 962,
#         "humidity": 23,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 79.39,
#         "temp_max": 79.39,
#         "temp_min": 79.39
#     },
#     "name": "Kolokani",
#     "sys": {
#         "country": "ML",
#         "sunrise": 1651039950,
#         "sunset": 1651085208
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "gust": 19.06,
#         "speed": 7.94
#     }
# }
# Processing Record 28 of Set 1 | kolokani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=bluff
# {
#     "base": "stations",
#     "clouds": {
#         "all": 21
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.6,
#         "lon": 168.3333
#     },
#     "dt": 1651023020,
#     "id": 2206939,
#     "main": {
#         "feels_like": 54.23,
#         "grnd_level": 1024,
#         "humidity": 67,
#         "pressure": 1027,
#         "sea_level": 1027,
#         "temp": 55.8,
#         "temp_max": 55.8,
#         "temp_min": 55.8
#     },
#     "name": "Bluff",
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1651001924,
#         "sunset": 1651038586,
#         "type": 2
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "gust": 8.95,
#         "speed": 7.47
#     }
# }
# Processing Record 29 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=dikson
# {
#     "base": "stations",
#     "clouds": {
#         "all": 88
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 73.5069,
#         "lon": 80.5464
#     },
#     "dt": 1651022940,
#     "id": 1507390,
#     "main": {
#         "feels_like": -3.41,
#         "grnd_level": 1006,
#         "humidity": 94,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 9.19,
#         "temp_max": 9.19,
#         "temp_min": 9.19
#     },
#     "name": "Dikson",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1651004961,
#         "sunset": 1651077683
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "gust": 13.78,
#         "speed": 8.88
#     }
# }
# Processing Record 30 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=port+augusta
# {
#     "base": "stations",
#     "clouds": {
#         "all": 9
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -32.5,
#         "lon": 137.7667
#     },
#     "dt": 1651022806,
#     "id": 2063056,
#     "main": {
#         "feels_like": 67.28,
#         "grnd_level": 1012,
#         "humidity": 70,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 67.53,
#         "temp_max": 67.53,
#         "temp_min": 67.53
#     },
#     "name": "Port Augusta",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1651007888,
#         "sunset": 1651047293
#     },
#     "timezone": 34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 323,
#         "gust": 3.38,
#         "speed": 3.65
#     }
# }
# Processing Record 31 of Set 1 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=thompson
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.7435,
#         "lon": -97.8558
#     },
#     "dt": 1651023159,
#     "id": 6165406,
#     "main": {
#         "feels_like": 34.43,
#         "humidity": 24,
#         "pressure": 1027,
#         "temp": 39.36,
#         "temp_max": 39.36,
#         "temp_min": 39.36
#     },
#     "name": "Thompson",
#     "sys": {
#         "country": "CA",
#         "id": 935,
#         "sunrise": 1650970763,
#         "sunset": 1651024723,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 6.91
#     }
# }
# Processing Record 32 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=puerto+ayora
# {
#     "base": "stations",
#     "clouds": {
#         "all": 26
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.7393,
#         "lon": -90.3518
#     },
#     "dt": 1651022943,
#     "id": 3652764,
#     "main": {
#         "feels_like": 73.71,
#         "grnd_level": 1005,
#         "humidity": 86,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 72.7,
#         "temp_max": 72.7,
#         "temp_min": 72.7
#     },
#     "name": "Puerto Ayora",
#     "sys": {
#         "country": "EC",
#         "sunrise": 1650974180,
#         "sunset": 1651017704
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 156,
#         "gust": 5.06,
#         "speed": 4.29
#     }
# }
# Processing Record 33 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=san+andres
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.5847,
#         "lon": -81.7006
#     },
#     "dt": 1651023005,
#     "id": 3670218,
#     "main": {
#         "feels_like": 87.19,
#         "humidity": 89,
#         "pressure": 1011,
#         "temp": 80.62,
#         "temp_max": 80.62,
#         "temp_min": 80.62
#     },
#     "name": "San Andr\u00e9s",
#     "sys": {
#         "country": "CO",
#         "id": 8623,
#         "sunrise": 1650971314,
#         "sunset": 1651016418,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity drizzle",
#             "icon": "09n",
#             "id": 300,
#             "main": "Drizzle"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 10.36
#     }
# }
# Processing Record 34 of Set 1 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=provideniya
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.3833,
#         "lon": -173.3
#     },
#     "dt": 1651023159,
#     "id": 4031574,
#     "main": {
#         "feels_like": 18.79,
#         "humidity": 80,
#         "pressure": 1024,
#         "temp": 28.51,
#         "temp_max": 28.51,
#         "temp_min": 28.36
#     },
#     "name": "Provideniya",
#     "sys": {
#         "country": "RU",
#         "id": 8875,
#         "sunrise": 1651072574,
#         "sunset": 1651131904,
#         "type": 1
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 11.18
#     }
# }
# Processing Record 35 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=busselton
# {
#     "base": "stations",
#     "clouds": {
#         "all": 12
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.65,
#         "lon": 115.3333
#     },
#     "dt": 1651022936,
#     "id": 2075265,
#     "main": {
#         "feels_like": 59.59,
#         "grnd_level": 1003,
#         "humidity": 77,
#         "pressure": 1003,
#         "sea_level": 1003,
#         "temp": 60.24,
#         "temp_max": 60.24,
#         "temp_min": 60.24
#     },
#     "name": "Busselton",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1651013369,
#         "sunset": 1651052579
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 184,
#         "gust": 13.13,
#         "speed": 7.47
#     }
# }
# Processing Record 36 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=airai
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.9266,
#         "lon": 125.4092
#     },
#     "dt": 1651022942,
#     "id": 1651810,
#     "main": {
#         "feels_like": 70.45,
#         "grnd_level": 859,
#         "humidity": 60,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 70.84,
#         "temp_max": 70.84,
#         "temp_min": 70.84
#     },
#     "name": "Airai",
#     "sys": {
#         "country": "TL",
#         "sunrise": 1651009275,
#         "sunset": 1651051837
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 183,
#         "gust": 2.89,
#         "speed": 2.24
#     }
# }
# Processing Record 37 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=tuatapere
# {
#     "base": "stations",
#     "clouds": {
#         "all": 91
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.1333,
#         "lon": 167.6833
#     },
#     "dt": 1651022798,
#     "id": 2180815,
#     "main": {
#         "feels_like": 54.77,
#         "grnd_level": 1024,
#         "humidity": 81,
#         "pressure": 1027,
#         "sea_level": 1027,
#         "temp": 55.69,
#         "temp_max": 55.69,
#         "temp_min": 55.69
#     },
#     "name": "Tuatapere",
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1651002024,
#         "sunset": 1651038798
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "gust": 8.61,
#         "speed": 5.75
#     }
# }
# Processing Record 38 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=ahipara
# {
#     "base": "stations",
#     "clouds": {
#         "all": 44
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.1667,
#         "lon": 173.1667
#     },
#     "dt": 1651023160,
#     "id": 2194098,
#     "main": {
#         "feels_like": 65.98,
#         "grnd_level": 1020,
#         "humidity": 56,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 66.96,
#         "temp_max": 66.96,
#         "temp_min": 66.96
#     },
#     "name": "Ahipara",
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1650999608,
#         "sunset": 1651038582
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 179,
#         "gust": 11.07,
#         "speed": 9.35
#     }
# }
# Processing Record 39 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=kodiak
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 57.79,
#         "lon": -152.4072
#     },
#     "dt": 1651022905,
#     "id": 5866583,
#     "main": {
#         "feels_like": 50.34,
#         "humidity": 47,
#         "pressure": 1014,
#         "temp": 53.11,
#         "temp_max": 53.11,
#         "temp_min": 53.11
#     },
#     "name": "Saint Paul Harbor",
#     "sys": {
#         "country": "US",
#         "id": 7668,
#         "sunrise": 1650983379,
#         "sunset": 1651038289,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "gust": 20.71,
#         "speed": 12.66
#     }
# }
# Processing Record 40 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=cape+town
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.9258,
#         "lon": 18.4232
#     },
#     "dt": 1651022993,
#     "id": 3369157,
#     "main": {
#         "feels_like": 57.56,
#         "humidity": 73,
#         "pressure": 1021,
#         "temp": 58.57,
#         "temp_max": 59.92,
#         "temp_min": 55.11
#     },
#     "name": "Cape Town",
#     "sys": {
#         "country": "ZA",
#         "id": 2073005,
#         "sunrise": 1651036662,
#         "sunset": 1651075798,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 13.8
#     }
# }
# Processing Record 41 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=kavieng
# {
#     "base": "stations",
#     "clouds": {
#         "all": 16
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.5744,
#         "lon": 150.7967
#     },
#     "dt": 1651023160,
#     "id": 2094342,
#     "main": {
#         "feels_like": 93.6,
#         "grnd_level": 1005,
#         "humidity": 68,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 85.73,
#         "temp_max": 85.73,
#         "temp_min": 85.73
#     },
#     "name": "Kavieng",
#     "rain": {
#         "1h": 0.11
#     },
#     "sys": {
#         "country": "PG",
#         "sunrise": 1651002809,
#         "sunset": 1651046118
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "gust": 17.36,
#         "speed": 16.44
#     }
# }
# Processing Record 42 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=chancay
# {
#     "base": "stations",
#     "clouds": {
#         "all": 82
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -11.5714,
#         "lon": -77.2672
#     },
#     "dt": 1651023160,
#     "id": 3944399,
#     "main": {
#         "feels_like": 66.99,
#         "grnd_level": 1008,
#         "humidity": 91,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 66.38,
#         "temp_max": 66.38,
#         "temp_min": 66.38
#     },
#     "name": "Chancay",
#     "sys": {
#         "country": "PE",
#         "sunrise": 1650971673,
#         "sunset": 1651013932
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 184,
#         "gust": 6.53,
#         "speed": 5.7
#     }
# }
# Processing Record 43 of Set 1 | chancay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=laela
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.5667,
#         "lon": 32.05
#     },
#     "dt": 1651023161,
#     "id": 156098,
#     "main": {
#         "feels_like": 60.22,
#         "grnd_level": 845,
#         "humidity": 98,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 59.92,
#         "temp_max": 59.92,
#         "temp_min": 59.92
#     },
#     "name": "Laela",
#     "sys": {
#         "country": "TZ",
#         "sunrise": 1651031661,
#         "sunset": 1651074259
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 194,
#         "gust": 7.47,
#         "speed": 3
#     }
# }
# Processing Record 44 of Set 1 | laela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=korla
# {
#     "base": "stations",
#     "clouds": {
#         "all": 2
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.7597,
#         "lon": 86.1469
#     },
#     "dt": 1651023161,
#     "id": 1529376,
#     "main": {
#         "feels_like": 55.22,
#         "grnd_level": 912,
#         "humidity": 41,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": 57.81,
#         "temp_max": 57.81,
#         "temp_min": 57.81
#     },
#     "name": "Korla",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1651015068,
#         "sunset": 1651064887
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 46,
#         "gust": 14.94,
#         "speed": 14.36
#     }
# }
# Processing Record 45 of Set 1 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=itarema
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.9248,
#         "lon": -39.9167
#     },
#     "dt": 1651023161,
#     "id": 3393692,
#     "main": {
#         "feels_like": 77.72,
#         "grnd_level": 1009,
#         "humidity": 87,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 76.3,
#         "temp_max": 76.3,
#         "temp_min": 76.3
#     },
#     "name": "Itarema",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1650962203,
#         "sunset": 1651005475
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "gust": 19.3,
#         "speed": 9.62
#     }
# }
# Processing Record 46 of Set 1 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=castro
# {
#     "base": "stations",
#     "clouds": {
#         "all": 88
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -24.7911,
#         "lon": -50.0119
#     },
#     "dt": 1651022944,
#     "id": 3466704,
#     "main": {
#         "feels_like": 63.09,
#         "grnd_level": 905,
#         "humidity": 92,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 62.78,
#         "temp_max": 62.78,
#         "temp_min": 62.78
#     },
#     "name": "Castro",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1650965968,
#         "sunset": 1651006556
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 10,
#         "gust": 4.45,
#         "speed": 4.09
#     }
# }
# Processing Record 47 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=saint-philippe
# {
#     "base": "stations",
#     "clouds": {
#         "all": 46
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.3585,
#         "lon": 55.7679
#     },
#     "dt": 1651022947,
#     "id": 935215,
#     "main": {
#         "feels_like": 73.89,
#         "grnd_level": 1007,
#         "humidity": 83,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 72.99,
#         "temp_max": 72.99,
#         "temp_min": 72.21
#     },
#     "name": "Saint-Philippe",
#     "rain": {
#         "1h": 0.58
#     },
#     "sys": {
#         "country": "RE",
#         "id": 2127,
#         "sunrise": 1651026767,
#         "sunset": 1651067769,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 52,
#         "gust": 6.98,
#         "speed": 6.62
#     }
# }
# Processing Record 48 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=boyolangu
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.1181,
#         "lon": 111.8935
#     },
#     "dt": 1651023162,
#     "id": 1648082,
#     "main": {
#         "feels_like": 89.71,
#         "grnd_level": 999,
#         "humidity": 73,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 83.23,
#         "temp_max": 83.23,
#         "temp_min": 83.23
#     },
#     "name": "Boyolangu",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1651012471,
#         "sunset": 1651055128
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 2,
#         "gust": 6.15,
#         "speed": 3.53
#     }
# }
# Processing Record 49 of Set 1 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=sentyabrskiy
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Processing Record 50 of Set 1 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=raudeberg
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 61.9875,
#         "lon": 5.1352
#     },
#     "dt": 1651023162,
#     "id": 3146487,
#     "main": {
#         "feels_like": 27.9,
#         "humidity": 73,
#         "pressure": 1026,
#         "temp": 37.87,
#         "temp_max": 38.07,
#         "temp_min": 34.95
#     },
#     "name": "Raudeberg",
#     "sys": {
#         "country": "NO",
#         "id": 2003008,
#         "sunrise": 1651030714,
#         "sunset": 1651088124,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 34,
#         "gust": 21.59,
#         "speed": 19.17
#     }
# }
# Processing Record 1 of Set 2 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=klaksvik
# {
#     "base": "stations",
#     "clouds": {
#         "all": 79
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.2266,
#         "lon": -6.589
#     },
#     "dt": 1651023163,
#     "id": 2618795,
#     "main": {
#         "feels_like": 26.8,
#         "grnd_level": 1027,
#         "humidity": 66,
#         "pressure": 1030,
#         "sea_level": 1030,
# ...
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 77.31,
#         "temp_max": 77.31,
#         "temp_min": 77.31
#     },
#     "name": "Maragogi",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1650961430,
#         "sunset": 1651003995
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 113,
#         "gust": 13.24,
#         "speed": 8.48
#     }
# }
# Processing Record 28 of Set 3 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=bereda
# {
#     "base": "stations",
#     "clouds": {
#         "all": 22
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.2686,
#         "lon": -7.5406
#     },
#     "dt": 1651023180,
#     "id": 3105522,
#     "main": {
#         "feels_like": 43.14,
#         "grnd_level": 966,
#         "humidity": 100,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 43.14,
#         "temp_max": 49.57,
#         "temp_min": 43.14
#     },
#     "name": "Bereda",
#     "sys": {
#         "country": "ES",
#         "id": 2013071,
#         "sunrise": 1651037356,
#         "sunset": 1651087566,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 218,
#         "gust": 1.48,
#         "speed": 1.28
#     }
# }
# Processing Record 29 of Set 3 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=eureka
# {
#     "base": "stations",
#     "clouds": {
#         "all": 60
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 40.8021,
#         "lon": -124.1637
#     },
#     "dt": 1651023180,
#     "id": 5563397,
#     "main": {
#         "feels_like": 52.29,
#         "humidity": 76,
#         "pressure": 1020,
#         "temp": 53.65,
#         "temp_max": 54.57,
#         "temp_min": 51.19
#     },
#     "name": "Eureka",
#     "sys": {
#         "country": "US",
#         "id": 2007742,
#         "sunrise": 1650979283,
#         "sunset": 1651028829,
#         "type": 2
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "gust": 14,
#         "speed": 8.01
#     }
# }
# Processing Record 30 of Set 3 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=miraflores
# {
#     "base": "stations",
#     "clouds": {
#         "all": 97
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 19.2167,
#         "lon": -98.8083
#     },
#     "dt": 1651023181,
#     "id": 3761194,
#     "main": {
#         "feels_like": 64.2,
#         "grnd_level": 779,
#         "humidity": 64,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": 64.99,
#         "temp_max": 65.05,
#         "temp_min": 57.96
#     },
#     "name": "Miraflores",
#     "sys": {
#         "country": "MX",
#         "id": 7146,
#         "sunrise": 1650974994,
#         "sunset": 1651020949,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 88,
#         "gust": 6.46,
#         "speed": 4.34
#     }
# }
# Processing Record 31 of Set 3 | miraflores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=saint-francois
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.4154,
#         "lon": 3.9054
#     },
#     "dt": 1651023181,
#     "id": 2980080,
#     "main": {
#         "feels_like": 38.64,
#         "humidity": 93,
#         "pressure": 1019,
#         "temp": 38.64,
#         "temp_max": 42.67,
#         "temp_min": 38.64
#     },
#     "name": "Saint-Fran\u00e7ois",
#     "sys": {
#         "country": "FR",
#         "id": 6499,
#         "sunrise": 1651034211,
#         "sunset": 1651085217,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 0
#     }
# }
# Processing Record 32 of Set 3 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=paratinga
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -12.6906,
#         "lon": -43.1842
#     },
#     "dt": 1651023181,
#     "id": 3455029,
#     "main": {
#         "feels_like": 73.17,
#         "grnd_level": 965,
#         "humidity": 61,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 73.27,
#         "temp_max": 73.27,
#         "temp_min": 73.27
#     },
#     "name": "Paratinga",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1650963559,
#         "sunset": 1651005688
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 81,
#         "gust": 21.99,
#         "speed": 6.11
#     }
# }
# Processing Record 33 of Set 3 | paratinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=albany
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6001,
#         "lon": -73.9662
#     },
#     "dt": 1651023042,
#     "id": 5106841,
#     "main": {
#         "feels_like": 46.17,
#         "humidity": 88,
#         "pressure": 1013,
#         "temp": 48.25,
#         "temp_max": 51.22,
#         "temp_min": 45.73
#     },
#     "name": "Albany",
#     "rain": {
#         "1h": 1.22
#     },
#     "sys": {
#         "country": "US",
#         "id": 19530,
#         "sunrise": 1650967047,
#         "sunset": 1651016973,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10n",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 274,
#         "gust": 20,
#         "speed": 5.01
#     }
# }
# Processing Record 34 of Set 3 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=gualeguay
# {
#     "base": "stations",
#     "clouds": {
#         "all": 34
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.1416,
#         "lon": -59.3097
#     },
#     "dt": 1651023182,
#     "id": 3433663,
#     "main": {
#         "feels_like": 75.34,
#         "grnd_level": 996,
#         "humidity": 93,
#         "pressure": 997,
#         "sea_level": 997,
#         "temp": 73.89,
#         "temp_max": 73.89,
#         "temp_min": 73.89
#     },
#     "name": "Gualeguay",
#     "sys": {
#         "country": "AR",
#         "sunrise": 1650968818,
#         "sunset": 1651008167
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 353,
#         "gust": 40.51,
#         "speed": 14.36
#     }
# }
# Processing Record 35 of Set 3 | gualeguay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=innisfail
# {
#     "base": "stations",
#     "clouds": {
#         "all": 72
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -17.5333,
#         "lon": 146.0333
#     },
#     "dt": 1651023182,
#     "id": 2162683,
#     "main": {
#         "feels_like": 84.96,
#         "grnd_level": 1009,
#         "humidity": 75,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 80.73,
#         "temp_max": 80.73,
#         "temp_min": 80.73
#     },
#     "name": "Innisfail",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1651004850,
#         "sunset": 1651046363
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 147,
#         "gust": 13.47,
#         "speed": 10.58
#     }
# }
# Processing Record 36 of Set 3 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=tuktoyaktuk
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 69.4541,
#         "lon": -133.0374
#     },
#     "dt": 1651023182,
#     "id": 6170031,
#     "main": {
#         "feels_like": 6.06,
#         "humidity": 92,
#         "pressure": 1026,
#         "temp": 15.8,
#         "temp_max": 15.8,
#         "temp_min": 15.8
#     },
#     "name": "Tuktoyaktuk",
#     "sys": {
#         "country": "CA",
#         "id": 942,
#         "sunrise": 1650974137,
#         "sunset": 1651038235,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 10,
#         "speed": 6.91
#     }
# }
# Processing Record 37 of Set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=upernavik
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 72.7868,
#         "lon": -56.1549
#     },
#     "dt": 1651023183,
#     "id": 3418910,
#     "main": {
#         "feels_like": 20.25,
#         "grnd_level": 1013,
#         "humidity": 76,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 25.7,
#         "temp_max": 25.7,
#         "temp_min": 25.7
#     },
#     "name": "Upernavik",
#     "sys": {
#         "country": "GL",
#         "sunrise": 1650952716,
#         "sunset": 1651022756
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 58,
#         "gust": 4.45,
#         "speed": 4.47
#     }
# }
# Processing Record 38 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=hithadhoo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.6,
#         "lon": 73.0833
#     },
#     "dt": 1651023183,
#     "id": 1282256,
#     "main": {
#         "feels_like": 92.14,
#         "grnd_level": 1008,
#         "humidity": 72,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 84.43,
#         "temp_max": 84.43,
#         "temp_min": 84.43
#     },
#     "name": "Hithadhoo",
#     "sys": {
#         "country": "MV",
#         "sunrise": 1651021343,
#         "sunset": 1651064883
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 309,
#         "gust": 5.99,
#         "speed": 5.99
#     }
# }
# Processing Record 39 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=yanam
# {
#     "base": "stations",
#     "clouds": {
#         "all": 6
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 16.7333,
#         "lon": 82.2167
#     },
#     "dt": 1651023183,
#     "id": 1252795,
#     "main": {
#         "feels_like": 95.56,
#         "grnd_level": 1008,
#         "humidity": 70,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 86.2,
#         "temp_max": 86.2,
#         "temp_min": 86.2
#     },
#     "name": "Yanam",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1651018094,
#         "sunset": 1651063748
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 243,
#         "gust": 8.1,
#         "speed": 4.52
#     }
# }
# Processing Record 40 of Set 3 | yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=saldanha
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.0117,
#         "lon": 17.9442
#     },
#     "dt": 1651023184,
#     "id": 3361934,
#     "main": {
#         "feels_like": 54.93,
#         "grnd_level": 1016,
#         "humidity": 79,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": 55.92,
#         "temp_max": 55.92,
#         "temp_min": 55.92
#     },
#     "name": "Saldanha",
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1651036702,
#         "sunset": 1651075988
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 147,
#         "gust": 14.5,
#         "speed": 10.02
#     }
# }
# Processing Record 41 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=qaanaaq
# {
#     "base": "stations",
#     "clouds": {
#         "all": 81
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 77.484,
#         "lon": -69.3632
#     },
#     "dt": 1651022943,
#     "id": 3831208,
#     "main": {
#         "feels_like": 0.99,
#         "grnd_level": 1013,
#         "humidity": 67,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 12.09,
#         "temp_max": 12.09,
#         "temp_min": 12.09
#     },
#     "name": "Qaanaaq",
#     "sys": {
#         "country": "GL",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 37,
#         "gust": 7.4,
#         "speed": 7.56
#     }
# }
# Processing Record 42 of Set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=hamilton
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.1834,
#         "lon": -84.5333
#     },
#     "dt": 1651022946,
#     "id": 4513583,
#     "main": {
#         "feels_like": 44.1,
#         "humidity": 60,
#         "pressure": 1024,
#         "temp": 48.2,
#         "temp_max": 51.24,
#         "temp_min": 44.11
#     },
#     "name": "Hamilton",
#     "sys": {
#         "country": "US",
#         "id": 2005257,
#         "sunrise": 1650969952,
#         "sunset": 1651019140,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 9.22
#     }
# }
# Processing Record 43 of Set 3 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=997985adc94dc02a9da0ce3dbb04a616&q=mys+shmidta
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Processing Record 44 of Set 3 | mys shmidta
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0  Bredasdorp -34.5322   20.0403     53.24           clear sky        83
# 1     Ushuaia -54.8000  -68.3000     38.86       broken clouds        81
# 2       Asind  25.7333   74.3333     87.06           clear sky        28
# 3  Mehtar Lam  34.6714   70.2094     78.30          few clouds        19
# 4       Vaini -21.2000 -175.2000     78.96          few clouds        61
# 5    Souillac -20.5167   57.5167     73.78          few clouds        88
# 6       Sembe   1.6481   14.5806     68.68     overcast clouds        98
# 7  Nikolskoye  59.7035   30.7861     34.88       broken clouds        94
# 8    Goderich  43.7501  -81.7165     35.91          light snow        86
# 9       Gusau  12.1628    6.6614     84.92     overcast clouds        17
#
#    Cloudiness  Wind Speed Country
# 0           0        3.44      ZA
# 1          75       16.11      AR
# 2           0       16.58      IN
# 3          13        4.70      AF
# 4          20       14.97      TO
# 5          20        9.22      MU
# 6         100        2.01      CG
# 7          67        4.52      RU
# 8          96        5.75      CA
# 9          86        7.11      NG

# %%
city_data_df = pd.DataFrame(city_data)
print(city_data_df)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0    Bredasdorp -34.5322   20.0403     53.24           clear sky        83
# 1       Ushuaia -54.8000  -68.3000     38.86       broken clouds        81
# 2         Asind  25.7333   74.3333     87.06           clear sky        28
# 3    Mehtar Lam  34.6714   70.2094     78.30          few clouds        19
# 4         Vaini -21.2000 -175.2000     78.96          few clouds        61
# ..          ...      ...       ...       ...                 ...       ...
# 125   Hithadhoo  -0.6000   73.0833     84.43     overcast clouds        72
# 126       Yanam  16.7333   82.2167     86.20           clear sky        70
# 127    Saldanha -33.0117   17.9442     55.92           clear sky        79
# 128     Qaanaaq  77.4840  -69.3632     12.09       broken clouds        67
# 129    Hamilton  39.1834  -84.5333     51.24           clear sky        60
#
#      Cloudiness  Wind Speed Country
# 0             0        3.44      ZA
# 1            75       16.11      AR
# 2             0       16.58      IN
# 3            13        4.70      AF
# 4            20       14.97      TO
# ..          ...         ...     ...
# 125         100        5.99      MV
# 126           6        4.52      IN
# 127           0       10.02      ZA
# 128          81        7.56      GL
# 129           0        9.22      US
#
# [130 rows x 9 columns]

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed",
                    "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bredasdorp      ZA -34.5322   20.0403     53.24        83           0
# 1     Ushuaia      AR -54.8000  -68.3000     38.86        81          75
# 2       Asind      IN  25.7333   74.3333     87.06        28           0
# 3  Mehtar Lam      AF  34.6714   70.2094     78.30        19          13
# 4       Vaini      TO -21.2000 -175.2000     78.96        61          20
# 5    Souillac      MU -20.5167   57.5167     73.78        88          20
# 6       Sembe      CG   1.6481   14.5806     68.68        98         100
# 7  Nikolskoye      RU  59.7035   30.7861     34.88        94          67
# 8    Goderich      CA  43.7501  -81.7165     35.91        86          96
# 9       Gusau      NG  12.1628    6.6614     84.92        17          86
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1       16.11       broken clouds
# 2       16.58           clear sky
# 3        4.70          few clouds
# 4       14.97          few clouds
# 5        9.22          few clouds
# 6        2.01     overcast clouds
# 7        4.52       broken clouds
# 8        5.75          light snow
# 9        7.11     overcast clouds

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
